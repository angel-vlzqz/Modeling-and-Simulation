# %%
import matplotlib
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import numpy as np

# User inserts r value
print('What is the value of r: ')
r = float(input())
# This is Xo
initial = 0.02
array = []
array.append(initial)
#For loop finds the next term in the sequence and stores it in an array to be plotted later
for x in range(100):
       initial = r * initial * (1 - initial)
       array.append(initial)

print(array)
#Matplotlib functions to graph the array
plt.plot(array)
plt.title('Logistic Exercise')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# What is the value of r:
# [0.02, 0.0392, 0.07532672, 0.1393052105080832, 0.23979853766676365, 0.36459039799929077, 0.463328479372019, 0.4973103991496632, 0.49998553209453167, 0.49999999958135943, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
